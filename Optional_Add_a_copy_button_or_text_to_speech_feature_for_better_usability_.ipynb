# %%
# Install required packages
# !pip install deep-translator gTTS --quiet

from deep_translator import GoogleTranslator
from gtts import gTTS
from IPython.display import Audio, display, HTML

# === INPUT TEXT AND LANGUAGE ===
source_text = "Hello, how are you?"
target_language = "te"  # Telugu

# === TRANSLATION ===
translated_text = GoogleTranslator(source='auto', target=target_language).translate(source_text)

# === DISPLAY TRANSLATED TEXT ===
print("Original Text:", source_text)
print("Translated Text:", translated_text)

# === COPY BUTTON ===
display(HTML(f'''
    <textarea id="translated" rows="3" cols="60">{translated_text}</textarea><br>
    <button onclick="navigator.clipboard.writeText(document.getElementById('translated').value)">Copy Translated Text</button>
'''))

# === TEXT-TO-SPEECH (TTS) ===
tts = gTTS(text=translated_text, lang=target_language)
tts.save("translated.mp3")
display(Audio("translated.mp3", autoplay=True))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.0 MB/s eta 0:00:00
# Original Text: Hello, how are you?
# Translated Text: హలో, మీరు ఎలా ఉన్నారు?
#     <textarea id="translated" rows="3" cols="60">హలో, మీరు ఎలా ఉన్నారు?</textarea><br>
#     <button onclick="navigator.clipboard.writeText(document.getElementById('translated').value)">Copy Translated Text</button>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
